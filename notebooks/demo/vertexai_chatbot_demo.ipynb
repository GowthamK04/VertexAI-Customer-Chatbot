# %%
# !gcloud auth application-default login

# %%
# !pip3 install --upgrade "google-cloud-aiplatform>=1.38"
# Out:
# Requirement already satisfied: google-cloud-aiplatform>=1.38 in /usr/local/lib/python3.10/dist-packages (1.67.1)
# Collecting google-cloud-aiplatform>=1.38
#   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (2.19.2)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (2.0.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform>=1.38) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform>=1.38) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform>=1.38) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform>=1.38) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform>=1.38) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform>=1.38) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform>=1.38) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform>=1.38) (0.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform>=1.38) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform>=1.38) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform>=1.38) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0dev->google-cloud-aiplatform>=1.38) (1.26.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform>=1.38) (1.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform>=1.38) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform>=1.38) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform>=1.38) (2024.8.30)
# Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 38.8 MB/s eta 0:00:00
# Installing collected packages: google-cloud-aiplatform
#   Attempting uninstall: google-cloud-aiplatform
#     Found existing installation: google-cloud-aiplatform 1.67.1
#     Uninstalling google-cloud-aiplatform-1.67.1:
#       Successfully uninstalled google-cloud-aiplatform-1.67.1
# Successfully installed google-cloud-aiplatform-1.70.0

# %%
# !gcloud auth application-default set-quota-project "zeta-pivot-438217-s0"
# Out:
# Credentials saved to file: [/content/.config/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
#
# Quota project "zeta-pivot-438217-s0" was added to ADC which can be used by Google client libraries for billing and quota. Note that some services may still bill the project owning the resource.

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project="zeta-pivot-438217-s0", location="us-central1")
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 256,
    "temperature": 0.2,
    "top_p": 0.8,
    "top_k": 40
}
model = TextGenerationModel.from_pretrained("text-bison")
response = model.predict(
    """Summarize the following conversation between a service rep and a customer in a few sentences. Use only the information from the conversation.

Service Rep: How may I assist you today?
Customer: I need to change the shipping address for an order.
Service Rep: Ok, I can help you with that if the order has not been fulfilled from our warehouse yet. But if it has already shipped, then you will need to contact the shipping provider. Do you have the order ID?
Customer: Yes, it\'s 88986367.
Service Rep: One minute please while I pull up your order information.
Customer: No problem
Service Rep: Ok, it looks like your order was shipped from our warehouse 2 days ago. It is now in the hands of  the shipping provider, so you will need to contact them to update your delivery details. You can track your order with the shipping provider here: https://www.shippingprovider.com
Customer: Sigh, ok.
Service Rep: Is there anything else I can help you with today?
Customer: No, thanks.""",
    **parameters
)
print(f"Response from Model: {response.text}")
# Out:
# Response from Model:  A customer contacted customer service to change the shipping address for an order. The service rep informed them that the order had already been shipped and provided the customer with a link to track the order and contact the shipping provider to update the delivery details. The customer was disappointed but understood the situation.

# %%
response = model.predict(
    """Ticket: I lost my credit card numbered 12345. Can you help with deactivating the card?
Category: Credit card

Ticket: I would like to change the address associated with my account. I have been calling the bank multiple times but couldn\'t get through. Please help me.
Category: Bank account services

Ticket: good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services. I wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt i have a right to know this information as a consumer chase account xxxx xxxx xxxx xxxx thanks in advance for your help
Category: Loans and Mortgages

Ticket: Customer: Hello, I\'m calling to ask about your credit card rewards programs.\\nBank: Hi, thank you for calling [bank name]. Can I have your name and customer ID, please?\\nCustomer: Sure, my name is [customer name] and my customer ID is 1312345681.\\nBank: Thank you, Mr./Ms. [customer name]. We offer a variety of credit card rewards programs to meet your needs. Would you like me to tell you more about them?
Category:
""",
    **parameters
# 36      3412345702  2023-10-31  16:50:00
# 37      3512345703  2023-10-31  16:55:00
# 38      3612345704  2023-10-31  17:00:00
# 39      3712345705  2023-10-31  17:05:00
# 40      3812345706  2023-10-31  17:10:00
# 41      3912345707  2023-10-31  17:15:00
#
#                                       call_transcript  \
# 0   Customer: Hello, I'm calling to check on the s...
# 1   Customer: Hello, I'm calling to inquire about ...
# 2   Customer: Hello, I'm calling to transfer money...
# 3   Customer: Hello, I'm calling to dispute a char...
# 4   Customer: Hello, I'm calling to ask about your...
# 5   Customer: Hello, I'm calling to open a busines...
# 6   Customer: Hello, I'm calling to ask about your...
# 7   Customer: Hello, I'm calling to ask about your...
# 8   Customer: Hello, I'm calling to report a lost ...
# 9   Customer: Hello, I'm calling to inquire about ...
# 10  Customer: Hello, I'm calling to ask about your...
# 11  Customer: Hello, I'm calling to ask about your...
# 12  Customer: Hello, I'm calling to ask about your...
# 13  Customer: Hello, I'm calling to ask about your...
# 14  Customer: Hello, I'm calling to ask about your...
# 15  Customer: Hello, I'm calling to ask about your...
# 16  Customer: Hello, I'm calling to ask about your...
# 17  Customer: Hello, I'm calling to ask about your...
# 18  Customer: Hello, I'm calling to inquire about ...
# 19  Customer: Hello, I'm calling to ask about your...
# 20  Customer: Hello, I'm calling to ask about your...
# 21  Customer: Hello, I'm calling to ask about your...
# 22  Customer: Hello, I'm calling to ask about your...
# 23  Customer: Hello, I'm calling to ask about your...
# 24  Customer: Hello, I'm calling to ask about your...
# 25  Customer: Hello, I'm calling to ask about your...
# 26  Customer: Hello, I'm calling to ask about your...
# 27  Customer: Hello, I'm calling to ask about your...
# 28  Customer: Hello, I'm calling to ask about your...
# 29  Customer: Hello, I'm calling to ask about your...
# 30  Customer: Hello, I'm calling to ask about your...
# 31  Customer: Hello, I'm calling to ask about your...
# 32  Customer: Hello, I'm calling to ask about your...
# 33  Customer: Hello, I'm calling to ask about your...
# 34  Customer: Hello, I'm calling to ask about your...
# 35  Customer: Hello, I'm calling to ask about your...
# 36  Customer: Hello, I'm calling to ask about your...
# 37  Customer: Hello, I'm calling to ask about your...
# 38  Customer: Hello, I'm calling to ask about your...
# 39  Customer: Hello, I'm calling to ask about your...
# 40  Customer: Hello, I'm calling to ask about your...
# 41  Customer: Hello, I'm calling to ask about your...
#
#                  Classification
# 0           Loans and Mortgages
# 1           Investment products
# 2         Bank account services
# 3                   Credit card
# 4           Loans and Mortgages
# 5         Bank account services
# 6         Bank account services
# 7           Loans and Mortgages
# 8         Bank account services
# 9           Loans and Mortgages
# 10          Loans and Mortgages
# 11          Loans and Mortgages
# 12          Loans and Mortgages
# 13                  Credit card
# 14        Bank account services
# 15        Bank account services
# 16          Investment services
# 17        Bank account services
# 18   Wealth management services
# 19        Bank account services
# 20                    Insurance
# 21        Bank account services
# 22        Bank account services
# 23                    Insurance
# 24        Bank account services
# 25        Bank account services
# 26        Bank account services
# 27        Bank account services
# 28            None of the above
# 29        Bank account services
# 30        Bank account services
# 31        Bank account services
# 32          Loans and Mortgages
# 33        Bank account services
# 34        Bank account services
# 35          Loans and Mortgages
# 36          Loans and Mortgages
# 37          Loans and Mortgages
# 38                  Credit card
# 39        Bank account services
# 40        Bank account services
# 41        Bank account services

# %%
import vertexai
from vertexai.language_models import ChatModel, InputOutputTextPair
from vertexai import generative_models

vertexai.init(project="zeta-pivot-438217-s0", location="us-central1")
chat_model = ChatModel.from_pretrained("chat-bison")
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 0.9,
    "top_p": 1,
    "top_k": 1
}
safety_settings={
          generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
          generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
          generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
          generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    }
chat = chat_model.start_chat(
    context="""""",
)
response = chat.send_message("""Hello. Please help extract the main issues from this customer\\\'s complaint:

I like to start off by saying my family loves your restaurant...I remember the days when our kids had birthday parties there. But the decline in service is scary and truly hurting the reputation. Our family went to your location on Jessup Rd in Summerville, SC, the other day. We drove up to the speaker and placed our order. Drove around and there was one car. That car was there a while then they pulled around to the other side. We moved up and waited 28 minutes, and watched about 4 other cars leave. In those 28 minutes, not one employee came to the window. We watched as they were talking and laughing with each other going back and forth in the lobby. We noticed that the people who were in front of us ended up going inside. We finally drove off and went to another restaurant. Fast easy and friendly service. I truly hope you guys can save BK. But I have to say I\\\'m so disappointed as a supporter.""", **parameters)
print(f"Response from Model: {response.text}")
response = chat.send_message("""How can we revise our practices or protocols to prevent future incidents like these?""", **parameters)
print(f"Response from Model: {response.text}")
response = chat.send_message("""tell me more about your insurance property""", **parameters)
print(f"Response from Model: {response.text}")
# Out:
# Response from Model:  Certainly! Here are the main issues based on the customer's complaint:
#
# - **Slow service:** The customer waited for 28 minutes at the drive-thru without being served, while observing employees socializing inside the restaurant.
#
# - **Lack of attention to customers:** No employees came to the window to acknowledge or assist the customer during the long wait.
#
# - **Poor customer service:** The customer noticed that other cars left the restaurant without being served, and those who went inside seemed to receive faster service. This suggests a lack of attention to drive-thru customers.
#
# - **Loss of reputation:** The customer expresses concern about the decline in service and its impact on the restaurant's reputation.
#
# - **Disappointment as a supporter:** The customer expresses disappointment as a long-time supporter of the restaurant, highlighting the gap between their positive past experiences and the current poor service.
# Response from Model:  Here are some strategies to help prevent similar incidents and improve the customer experience:
#
# **1. Reduce Wait Times:**
#    - Ensure adequate staffing during peak hours to handle the volume of orders.
#    - Streamline order-taking and payment processes to minimize waiting time.
#    - Consider implementing a digital ordering system to reduce the need for customers to wait at the speaker.
#
# **2. Enhance Communication:**
#    - Assign a dedicated staff member to monitor the drive-thru and address any issues promptly.
#    - Regularly communicate with customers waiting in line about potential delays or updates on their orders.
#    - Provide clear signage with estimated wait times to manage customer expectations.
#
# **3. Improve Customer Service:**
#    - Reinforce the importance of customer service to all employees, emphasizing the need to be attentive and responsive to customers' needs.
#    - Implement regular customer service training to ensure employees understand and adhere to the restaurant's service standards.
#    - Encourage employees to acknowledge customers, even during busy periods, and provide updates on their orders.
#
# **4. Monitor Feedback:**
#    - Actively seek and monitor customer feedback through surveys, social media, and other channels to identify and address any ongoing service issues.
#    - Use the feedback to make improvements and demonstrate to customers that their concerns are being taken seriously.
#
# **5. Reward and Recognize:**
#    - Implement an incentive system to reward employees for delivering excellent customer service.
#    - Recognize and celebrate employees who consistently demonstrate outstanding service to motivate others and reinforce positive behavior.
# Response from Model:  As an AI language model, I do not have personal insurance or property. I am a virtual chatbot designed to help you with text-based tasks and provide information. I do not own any physical possessions or have any insurance coverage.
